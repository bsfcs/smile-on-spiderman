# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
smile_on = pd.read_csv('smileon.csv', low_memory=False)

# %%
smile_on.head()
# Out:
#    CallReportNum              ReportVersion CallDateAndTimeStart  \
# 0       62945363      SMILE ON 60+ Clinical      5/15/2019 10:00
# 1       57949412      SMILE ON 60+ Clinical       7/1/2018 11:56
# 2       54186032      SMILE ON 60+ Clinical       6/28/2018 9:04
# 3       54184987      SMILE ON 60+ Clinical       6/28/2018 8:21
# 4       54184728  SMILE ON 60+ Registration       6/28/2018 8:09
#
#   CallDateAndTimeEnd  CallLength  CallerNum  CallerNumCount  PhoneWorkerNum  \
# 0    5/15/2019 11:00          60         -2              10          119473
# 1     7/1/2018 11:59           3         -2              10          116749
# 2     6/28/2018 9:05           1         -2              10          117266
# 3     6/28/2018 8:23           2         -2              10          117266
# 4     6/28/2018 8:20          11         -2              10          117266
#
#     CityName CountyName  ...  \
# 0        NaN        NaN  ...
# 1        NaN        NaN  ...
# ...

# %%
phone_worker_num = smile_on[['PhoneWorkerNum', 'EnteredByWorkerNum', 'O2=H2']]
phone_worker_num.head()
# Out:
#    PhoneWorkerNum  EnteredByWorkerNum  O2=H2
# 0          119473              119473   True
# 1          116749              116749   True
# 2          117266              117266   True
# 3          117266              117266   True
# 4          117266              117266   True

# %%
# o2_h2 = phone_worker_num[phone_worker_num['PhoneWorkerNum'] == 117266]
o2_h2 = phone_worker_num[phone_worker_num['O2=H2'] == False]
o2_h2
# Out:
#        PhoneWorkerNum  EnteredByWorkerNum  O2=H2
# 117            118820              116749  False
# 243            118820              117268  False
# 244            118820              117268  False
# 259            118820              117268  False
# 260            118843              116749  False
# ...               ...                 ...    ...
# 33451          134403              119515  False
# 33709          134403              119515  False
# 33855              -1              133204  False
# 34212          134403              119515  False
# 36007          135611              119515  False
#
# [116 rows x 3 columns]
