# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
smile_on = pd.read_csv('../data/smile_on.csv', encoding="ISO-8859-1",  low_memory=False, header=2)
#for line in open('u.item', encoding='ISO-8859-1'):
#read each line
smile_on.head()
# Out:
#    CallReportNum              ReportVersion CallDateAndTimeStart  \
# 0       81381827  SMILE ON 60+ Registration     11/25/2020 16:46
# 1       81379177  SMILE ON 60+ Registration     11/25/2020 15:40
# 2       81377435      SMILE ON 60+ Clinical     11/25/2020 15:02
# 3       81375215      SMILE ON 60+ Clinical     11/25/2020 14:17
# 4       81373934      SMILE ON 60+ Clinical     11/25/2020 13:50
#
#   CallDateAndTimeEnd  CallerNum  PhoneWorkerNum     CityName CountyName  \
# 0   11/25/2020 16:48    3859874          136529  Springfield  Robertson
# 1   11/25/2020 15:55    3859755           82341    Nashville   Davidson
# 2   11/25/2020 15:02    2518680          119506  Rogersville    Hawkins
# 3   11/25/2020 14:17    3231923          143703      Memphis     Shelby
# 4   11/25/2020 13:58         -1          135611          NaN        NaN
#
#   StateProvince  PostalCode  ... SMILE ON 60+ Screening - Last Screening Date  \
# 0            TN     37172.0  ...                                          NaN
# 1            TN     37212.0  ...                                          NaN
# 2            TN     37857.0  ...                                          NaN
# 3            TN     38104.0  ...                                          NaN
# 4            TN         NaN  ...                                   11/25/2020
#
#   SMILE ON 60+ Base-line Oral and Conditions Questions - Are you limited in what you can eat?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                NaN
#
#   SMILE ON 60+ Base-line Oral and Conditions Questions - Dental Clinic  \
# 0  Matthew Walker Comprehensive Health Center Inc...
# 1               Interfaith Dental Clinic - Nashville
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)  \
# 0                                                NaN
# 1                                                NaN
# 2  5650 - Add tooth to existing partial denture - 30
# 3  No Code - Denture step Mandibular: may be used...
# 4                                                NaN
#
#          SMILE ON 60+ Site Information - Enroller ID  \
# 0  Matthew Walker Comprehensive Health Center Inc...
# 1                                                NaN
# 2          Friends in Need Health Center - Kingsport
# 3          Christ Community Health Services- Frayser
# 4                      Neighborhood Health - Lebanon
#
#   SMILE ON 60+ Site Information - Enroller Location  \
# 0                                     Provider Site
# 1                              Health Assist Office
# 2                                     Provider Site
# 3                                     Provider Site
# 4                                               NaN
#
#   SMILE ON 60+ Treatment Plan - Is the treatment plan completed?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                NaN
# 4                                                NaN
#
#   SMILE ON 60+ Treatment Plan - Was a treatment plan developed?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                NaN
# 4                                                Yes
#
#   SMILE ON 60+ Treatment Plan - can chew and "social six" esthetics  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                NaN
# 4                                                 No
#
#   SMILE ON 60+ Verification of Eligibility - Transportation Arranged
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 21 columns]

# %%
smile_on = smile_on.rename(columns = {'SMILE ON 60+ Screening - Last Screening Date': 'Last_Screen_Date',
                                      'SMILE ON 60+ Case Management Information - Dental Clinic' : 'Case_Mgmt_Clinic',
                                      'SMILE ON 60+ Clinic Information - Is patient of record date if yes last seen?' :'Date_Last_Seen',
                                      'SMILE ON 60+ Clinic Information - Was initial appointment made?' :'Initial_Appt_Made',
                                      'SMILE ON 60+ Demographic Information - When is the last time you visited your dentist?': 'Last_Dentist_Visit',
                                      'SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)' : 'Care_Provided',
                                      'SMILE ON 60+ Screening - How often do you brush your teeth?' : 'Brush_Frequency',
                                      'SMILE ON 60+ Screening - Need for Periodontal Care' : 'Need_For_Care',
                                      'SMILE ON 60+ Screening - Root Fragments' : 'Root_Fragments',
                                      'SMILE ON 60+ Screening - Suspicious Soft Tissue Lesions' : 'Lesions',
                                      'SMILE ON 60+ Screening - Treatment Urgency' : 'Urgency',
                                      'SMILE ON 60+ Screening - Untreated Decay' : 'Decay',
                                      'SMILE ON 60+ Site Information - Enroller ID' : 'Clinic_Attended',
                                      'SMILE ON 60+ Treatment Plan - Is the treatment plan completed?' : 'Tx_Plan_Complete',
                                      'SMILE ON 60+ Treatment Plan - Was a treatment plan developed?' : 'Tx_Plan_Developed',
                                      'SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)' : 'Function_Restored',
                                      'SMILE ON 60+ Base-line Oral and Conditions Questions - Are you limited in what you can eat?': 'limited_eating',
                                      'SMILE ON 60+ Base-line Oral and Conditions Questions - Dental Clinic': 'dental_clinic',
                                      'SMILE ON 60+ Site Information - Enroller Location': 'enroller_location',
                                      'SMILE ON 60+ Treatment Plan - can chew and "social six" esthetics': 'social_six',
                                      'SMILE ON 60+ Verification of Eligibility - Transportation Arranged': 'transportation_arranged'
                                       })
smile_on.head()
# Out:
#    CallReportNum              ReportVersion CallDateAndTimeStart  \
# 0       81381827  SMILE ON 60+ Registration     11/25/2020 16:46
# 1       81379177  SMILE ON 60+ Registration     11/25/2020 15:40
# 2       81377435      SMILE ON 60+ Clinical     11/25/2020 15:02
# 3       81375215      SMILE ON 60+ Clinical     11/25/2020 14:17
# 4       81373934      SMILE ON 60+ Clinical     11/25/2020 13:50
#
#   CallDateAndTimeEnd  CallerNum  PhoneWorkerNum     CityName CountyName  \
# 0   11/25/2020 16:48    3859874          136529  Springfield  Robertson
# 1   11/25/2020 15:55    3859755           82341    Nashville   Davidson
# 2   11/25/2020 15:02    2518680          119506  Rogersville    Hawkins
# 3   11/25/2020 14:17    3231923          143703      Memphis     Shelby
# 4   11/25/2020 13:58         -1          135611          NaN        NaN
#
#   StateProvince  PostalCode  ... Last_Screen_Date limited_eating  \
# 0            TN     37172.0  ...              NaN             No
# 1            TN     37212.0  ...              NaN             No
# 2            TN     37857.0  ...              NaN             No
# 3            TN     38104.0  ...              NaN            Yes
# 4            TN         NaN  ...       11/25/2020            NaN
#
#                                        dental_clinic  \
# 0  Matthew Walker Comprehensive Health Center Inc...
# 1               Interfaith Dental Clinic - Nashville
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Care_Provided  \
# 0                                                NaN
# 1                                                NaN
# 2  5650 - Add tooth to existing partial denture - 30
# 3  No Code - Denture step Mandibular: may be used...
# 4                                                NaN
#
#                                      Clinic_Attended     enroller_location  \
# 0  Matthew Walker Comprehensive Health Center Inc...         Provider Site
# 1                                                NaN  Health Assist Office
# 2          Friends in Need Health Center - Kingsport         Provider Site
# 3          Christ Community Health Services- Frayser         Provider Site
# 4                      Neighborhood Health - Lebanon                   NaN
#
#   Tx_Plan_Complete Tx_Plan_Developed social_six transportation_arranged
# 0              NaN               NaN        NaN                     NaN
# 1              NaN               NaN        NaN                     NaN
# 2              Yes               Yes        Yes                     NaN
# 3              NaN               NaN        NaN                     NaN
# 4              NaN               Yes         No                     NaN
#
# [5 rows x 21 columns]

# %%
#change time format
smile_on['CallDateAndTimeStart'] = smile_on['CallDateAndTimeStart'].str.split(' ').apply(lambda x: str(x[0]))

# %%
visits = smile_on['CallerNum'].value_counts()

# %%
#create dataframe based on unique callers
patients = visits.to_frame().reset_index()
patients.head()
# Out:
#      index  CallerNum
# 0       -1         70
# 1  2441776         36
# 2  2431132         31
# 3  2416076         29
# 4  2466994         28

# %%
#fix columns
patients = patients.rename(columns = {'index': 'caller_num', 'CallerNum': 'number_of_visits'})
patients.head()
# Out:
#    caller_num  number_of_visits
# 0          -1                70
# 1     2441776                36
# 2     2431132                31
# 3     2416076                29
# 4     2466994                28

# %%
#remove unique callers -1,-2
patients = patients.loc[~patients['caller_num'].isin(['-1', '-2'])]
patients.shape
# Out:
# (8706, 2)

# %%
#add time column
patients['start_date'] = ''

for ind, row in smile_on.iterrows():
    patients.loc[ind, 'start_date'] = row['CallDateAndTimeStart']
patients.head()

# %%
#add care_provided column
patients['care_provided'] = ''

for ind, row in smile_on.iterrows():
    patients.loc[ind, 'care_provided'] = row['Care_Provided']
patients.head()
# Out:
#    caller_num  number_of_visits  \
# 1   2441776.0              36.0
# 2   2431132.0              31.0
# 3   2416076.0              29.0
# 4   2466994.0              28.0
# 5   2860770.0              28.0
#
#                                        care_provided
# 1                                                NaN
# 2  5650 - Add tooth to existing partial denture - 30
# 3  No Code - Denture step Mandibular: may be used...
# 4                                                NaN
# 5  No Code - Denture step Mandibular: may be used...

# %%
#add treatment plan column
patients['treatment_plan'] = ''

for ind, row in smile_on.iterrows():
    if row['Tx_Plan_Developed'] == 'Yes':
        patients.loc[ind, 'treatment_plan'] = ['treatment_plan'].count('Yes') + 1
    elif row['Tx_Plan_Developed'] == 'No':
        patients.loc[ind, 'treatment_plan'] ='no'
    else:
        patients.loc[ind, 'treatment_plan'] ='unknown'
patients.head()
# Out:
#    caller_num  number_of_visits  \
# 1   2441776.0              36.0
# 2   2431132.0              31.0
# 3   2416076.0              29.0
# 4   2466994.0              28.0
# 5   2860770.0              28.0
#
#                                        care_provided treatment_plan
# 1                                                NaN        unknown
# 2  5650 - Add tooth to existing partial denture - 30              1
# 3  No Code - Denture step Mandibular: may be used...        unknown
# 4                                                NaN              1
# 5  No Code - Denture step Mandibular: may be used...              1

# %%
#add treatment success column
patients['success'] = ''

for ind, row in smile_on.iterrows():
    if row['Tx_Plan_Complete'] == 'Yes':
        patients.loc[ind, 'success'] = ['success'].count('Yes') + 1
    elif row['Tx_Plan_Complete'] == 'No':
        patients.loc[ind, 'success'] ='no'
    else:
        patients.loc[ind, 'success'] ='unknown'
patients.head(25)
# Out:
#     caller_num  number_of_visits  \
# 1    2441776.0              36.0
# 2    2431132.0              31.0
# 3    2416076.0              29.0
# 4    2466994.0              28.0
# 5    2860770.0              28.0
# 6    2412580.0              26.0
# 7    2605896.0              25.0
# 8    3483924.0              25.0
# 9    2508895.0              25.0
# 10   2384974.0              24.0
# 11   2390065.0              23.0
# 12   2758336.0              23.0
# 13   2398755.0              23.0
# 14   2585132.0              23.0
# 15   2413871.0              23.0
# 16   2519897.0              23.0
# 17   2478100.0              22.0
# 18   2425664.0              22.0
# 19   3212379.0              22.0
# 20   2572538.0              22.0
# 21   2626906.0              22.0
# 22   2384932.0              22.0
# 23   2509118.0              22.0
# 24   2758373.0              22.0
# 25   2466431.0              22.0
#
#                                         care_provided treatment_plan  success
# 1                                                 NaN        unknown  unknown
# 2   5650 - Add tooth to existing partial denture - 30              1        1
# 3   No Code - Denture step Mandibular: may be used...        unknown  unknown
# 4                                                 NaN              1  unknown
# 5   No Code - Denture step Mandibular: may be used...              1       no
# 6                                                 NaN        unknown  unknown
# 7   No Code - Denture step Mandibular: may be used...              1       no
# 8                                                 NaN        unknown  unknown
# 9   140 - Limited Oral evaluation - problem focuse...             no        1
# 10                                                NaN        unknown  unknown
# 11                                                NaN        unknown  unknown
# 12    Tele0999 unspecified diagnostic procedure-  $50              1       no
# 13  No Code - Denture step Mandibular: may be used...        unknown       no
# 14                                                NaN        unknown  unknown
# 15  220 - Intraoral - Periapical First Film - 5; 2...        unknown  unknown
# 16  2335 - Resin four surfaces or w incis - Anteri...              1        1
# 17    Tele0999 unspecified diagnostic procedure-  $50              1       no
# 18                                                NaN        unknown  unknown
# 19                                                NaN        unknown  unknown
# 20                                                NaN        unknown  unknown
# 21                                                NaN        unknown  unknown
# 22           2392 - Posterior two surface resin  - 15              1       no
# 23  No Code - Denture step Mandibular: may be used...        unknown  unknown
# 24                                                NaN        unknown  unknown
# 25                                                NaN        unknown  unknown

# %%
#add social_six column
patients['social_six'] = ''

for ind, row in smile_on.iterrows():
    if row['social_six'] == 'Yes':
        patients.loc[ind, 'social_six'] = 'yes'
    elif row['social_six'] == 'No':
        patients.loc[ind, 'social_six'] ='no'
    else:
        patients.loc[ind, 'social_six'] ='unknown'
patients.head()
# Out:
#    caller_num  number_of_visits  \
# 1   2441776.0              36.0
# 2   2431132.0              31.0
# 3   2416076.0              29.0
# 4   2466994.0              28.0
# 5   2860770.0              28.0
#
#                                        care_provided treatment_plan  success  \
# 1                                                NaN        unknown  unknown
# 2  5650 - Add tooth to existing partial denture - 30              1        1
# 3  No Code - Denture step Mandibular: may be used...        unknown  unknown
# 4                                                NaN              1  unknown
# 5  No Code - Denture step Mandibular: may be used...              1       no
#
#   social_six
# 1    unknown
# 2        yes
# 3    unknown
# 4         no
# 5    unknown

# %%
#add postal code column
patients['postal_code'] = ''

for ind, row in smile_on.iterrows():
    patients.loc[ind, 'postal_code'] = row['PostalCode']
patients.head()
# Out:
#    caller_num  number_of_visits  \
# 1   2441776.0              36.0
# 2   2431132.0              31.0
# 3   2416076.0              29.0
# 4   2466994.0              28.0
# 5   2860770.0              28.0
#
#                                        care_provided treatment_plan  success  \
# 1                                                NaN        unknown  unknown
# 2  5650 - Add tooth to existing partial denture - 30              1        1
# 3  No Code - Denture step Mandibular: may be used...        unknown  unknown
# 4                                                NaN              1  unknown
# 5  No Code - Denture step Mandibular: may be used...              1       no
#
#   social_six postal_code
# 1    unknown       37212
# 2        yes       37857
# 3    unknown       38104
# 4         no         NaN
# 5    unknown       37664

# %%
#add clinic column
patients['clinic_attended'] = ''

for ind, row in smile_on.iterrows():
    patients.loc[ind, 'clinic_attended'] = row['Clinic_Attended']
patients.head()
# Out:
#    caller_num  number_of_visits  \
# 1   2441776.0              36.0
# 2   2431132.0              31.0
# 3   2416076.0              29.0
# 4   2466994.0              28.0
# 5   2860770.0              28.0
#
#                                        care_provided treatment_plan  success  \
# 1                                                NaN        unknown  unknown
# 2  5650 - Add tooth to existing partial denture - 30              1        1
# 3  No Code - Denture step Mandibular: may be used...        unknown  unknown
# 4                                                NaN              1  unknown
# 5  No Code - Denture step Mandibular: may be used...              1       no
#
#   social_six postal_code                            clinic_attended
# 1    unknown       37212                                        NaN
# 2        yes       37857  Friends in Need Health Center - Kingsport
# 3    unknown       38104  Christ Community Health Services- Frayser
# 4         no         NaN              Neighborhood Health - Lebanon
# 5    unknown       37664  Friends in Need Health Center - Kingsport
