# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
cms_payments = pd.read_csv('../data/cms_physician_and_other_supplier-payments_2015-2017.csv')
#for line in open('u.item', encoding='ISO-8859-1'):
#read each line
cms_payments.columns
# Out:
# Index(['year', 'National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %%
cms_payments.head()
# Out:
#    year  National Provider Identifier  \
# 0  2017                    1033112180
# 1  2017                    1043302466
# 2  2017                    1104009646
# 3  2017                    1104009646
# 4  2017                    1104031053
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                       TIPPS                     STEVEN
# 1                                       BLOCK                       JOHN
# 2                                    CAMPBELL                     JOSHUA
# 3                                    CAMPBELL                     JOSHUA
# 4                                     MANNION                       KYLE
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                              P                         DDS
# 1                            NaN                          MD
# 2                              A                         DDS
# ...

# %%
#df.loc[(df['First_name'] == 'Bill') | (df['First_name'] == 'Emma')
cms_payments=cms_payments.loc[cms_payments['year'].isin([2016,2017])] #df[df.Name.isin(['Alice', 'Bob'])]
#cms_payments = cms_payments.loc[cms_payments['year'] == 2016] | cms_payments.loc[cms_payments['year'] == 2017]
#cms_payments.head()
cms_payments.head()
# Out:
#    year  National Provider Identifier  \
# 0  2017                    1033112180
# 1  2017                    1043302466
# 2  2017                    1104009646
# 3  2017                    1104009646
# 4  2017                    1104031053
#
#   Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                       TIPPS                     STEVEN
# 1                                       BLOCK                       JOHN
# 2                                    CAMPBELL                     JOSHUA
# 3                                    CAMPBELL                     JOSHUA
# 4                                     MANNION                       KYLE
#
#   Middle Initial of the Provider Credentials of the Provider  \
# 0                              P                         DDS
# 1                            NaN                          MD
# 2                              A                         DDS
# ...

# %%
cms_payments = cms_payments[['City of the Provider',
                             'Average Submitted Charge Amount',
                             'Average Medicare Payment Amount']].copy()
cms_payments
# Out:
#    City of the Provider  Average Submitted Charge Amount  \
# 0           CHATTANOOGA                       104.400000
# 1             NASHVILLE                        80.000000
# 2             KNOXVILLE                      1970.000000
# 3             KNOXVILLE                        85.833333
# 4             NASHVILLE                      3614.000000
# ..                  ...                              ...
# 59            NASHVILLE                      7075.000000
# 60          CHATTANOOGA                       102.000000
# 61            KNOXVILLE                        84.000000
# 62            KNOXVILLE                      1815.000000
# 63            NASHVILLE                        80.000000
#
#     Average Medicare Payment Amount
# 0                         11.348000
# 1                          7.824074
# 2                        662.898333
# 3                         13.701667
# 4                        348.310000
# ..                              ...
# ...

# %%
cms_payments = cms_payments.rename(columns = {'City of the Provider':'city',
                                                'Average Submitted Charge Amount':'avg_submitted',
                                                'Average Medicare Payment Amount':'avg_medicare_payment'
                                               })

# %%
cms_payments['percent_covered']=(cms_payments['avg_medicare_payment']/cms_payments['avg_submitted'])*100
cms_payments.head()
# Out:
#           city  avg_submitted  avg_medicare_payment  percent_covered
# 0  CHATTANOOGA     104.400000             11.348000        10.869732
# 1    NASHVILLE      80.000000              7.824074         9.780093
# 2    KNOXVILLE    1970.000000            662.898333        33.649662
# 3    KNOXVILLE      85.833333             13.701667        15.963107
# 4    NASHVILLE    3614.000000            348.310000         9.637797

# %%
cms_payments=cms_payments.groupby(['city']).mean().reset_index()
cms_payments.info(25)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   city                  5 non-null      object
#  1   avg_submitted         5 non-null      float64
#  2   avg_medicare_payment  5 non-null      float64
#  3   percent_covered       5 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 288.0+ bytes

# %%
cms_payments['avg_submitted']=cms_payments['avg_submitted'].round(2)
cms_payments['avg_medicare_payment']=cms_payments['avg_medicare_payment'].round(2)
cms_payments['percent_covered']=cms_payments['percent_covered'].round(2)
cms_payments.head(15)
# Out:
#           city  avg_submitted  avg_medicare_payment  percent_covered
# 0  CHATTANOOGA          96.01                 12.70            16.10
# 1       HIXSON         327.73                236.46            72.47
# 2    KNOXVILLE         424.86                 77.72            20.19
# 3      MEMPHIS        3075.50                459.07            15.75
# 4    NASHVILLE         788.68                156.50            12.25

# %%
cms_payments['city']=cms_payments['city'].str.title()
cms_payments
# Out:
#           city  avg_submitted  avg_medicare_payment  percent_covered
# 0  Chattanooga          96.01                 12.70            16.10
# 1       Hixson         327.73                236.46            72.47
# 2    Knoxville         424.86                 77.72            20.19
# 3      Memphis        3075.50                459.07            15.75
# 4    Nashville         788.68                156.50            12.25

# %%
#export to csv
cms_payments.to_csv('../cms_payments.csv', index = False)
